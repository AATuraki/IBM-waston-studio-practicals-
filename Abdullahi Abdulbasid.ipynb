# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
#
# **ABDULLAHI ABDULBASID**
# am asipiring to become a certified data scientist
#
# *having passion of becoming a data scientist as an entreprenuer by profeesion. to solve real world problems from the ocean of data availables and untapped.*
#
# ###  multiplication of numeric

# %%
2 * 8
# Out:
# 16

# %% [markdown]
# <h2> abdullahi 2</h2>

# %% [markdown]
# -abdullahi-
# ***abdullahi***
# ![FB_IMG_1572278836784~2.jpg](attachment:FB_IMG_1572278836784~2.jpg)
